# %% [markdown]
# # Incremental learning on image classification
# Ablation studies

# %% [markdown]
# ## Libraries and packages

# %%
# !pip3 install 'torch==1.4.0'
# !pip3 install 'torchvision==0.5.0'
# !pip3 install 'Pillow-SIMD'
# !pip3 install 'tqdm'

# %%
import os
import urllib
import logging

import numpy as np

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
from torch.utils.data import Dataset, Subset, DataLoader, ConcatDataset
from torch.backends import cudnn

import torchvision
from torchvision import transforms
from torchvision.models import resnet34

from PIL import Image
from tqdm import tqdm

from copy import deepcopy

from sklearn.metrics import confusion_matrix

# %%
# GitHub credentials for cloning private repository
username = 'xolotl18'
password = ''

# Download packages from repository
password = urllib.parse.quote(password)
# !git clone https://$username:$password@github.com/manuelemacchia/incremental-learning-image-classification.git
password = ''

# !mv -v incremental-learning-image-classification/* .
# !rm -rf incremental-learning-image-classification README.md
# Out:
# Cloning into 'incremental-learning-image-classification'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 541 (delta 52), reused 11 (delta 4), pack-reused 444
# Receiving objects: 100% (541/541), 2.56 MiB | 2.43 MiB/s, done.
# Resolving deltas: 100% (281/281), done.
# renamed 'incremental-learning-image-classification/data' -> './data'
# renamed 'incremental-learning-image-classification/joint_training.ipynb' -> './joint_training.ipynb'
# renamed 'incremental-learning-image-classification/losses' -> './losses'
# renamed 'incremental-learning-image-classification/model' -> './model'
# renamed 'incremental-learning-image-classification/notebook.ipynb' -> './notebook.ipynb'
# renamed 'incremental-learning-image-classification/README.md' -> './README.md'
# renamed 'incremental-learning-image-classification/report' -> './report'
# renamed 'incremental-learning-image-classification/studies.ipynb' -> './studies.ipynb'
# renamed 'incremental-learning-image-classification/utils' -> './utils'

# %%
from data.cifar100 import Cifar100
from model.resnet_cifar import resnet32
from model.manager import Manager
from model.icarl import Exemplars
from model.icarl import iCaRL
from utils import plot
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Arguments

# %%
# Directories
DATA_DIR = 'data'       # Directory where the dataset will be downloaded

# Settings
DEVICE = 'cuda'

# Dataset

RANDOM_STATE = None

RANDOM_STATES = [658, 423, 422]      # For reproducibility of results                        
                                     # Note: different random states give very different
                                     # splits and therefore very different results.

NUM_CLASSES = 100       # Total number of classes
NUM_BATCHES = 10
CLASS_BATCH_SIZE = 10   # Size of batch of classes for incremental learning

VAL_SIZE = 0.1          # Proportion of validation set with respect to training set (between 0 and 1)

# Training
BATCH_SIZE = 64         # Batch size (iCaRL sets this to 128)
LR = 2                  # Initial learning rate
                       
MOMENTUM = 0.9          # Momentum for stochastic gradient descent (SGD)
WEIGHT_DECAY = 1e-5     # Weight decay from iCaRL

NUM_RUNS = 3            # Number of runs of every method
                        # Note: this should be at least 3 to have a fair benchmark

NUM_EPOCHS = 70         # Total number of training epochs
MILESTONES = [49, 63]   # Step down policy from iCaRL (MultiStepLR)
                        # Decrease the learning rate by gamma at each milestone
GAMMA = 0.2             # Gamma factor from iCaRL

# %% [markdown]
# ## Data preparation

# %%
# Transformations for Learning Without Forgetting
train_transform = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))                                    
])

# %%
train_subsets = [[] for i in range(NUM_RUNS)]
val_subsets = [[] for i in range(NUM_RUNS)]
test_subsets = [[] for i in range(NUM_RUNS)]

for run_i in range(NUM_RUNS):
    for split_i in range(CLASS_BATCH_SIZE):
        if run_i+split_i == 0: # Download dataset only at first instantiation
            download = True
        else:
            download = False

        # Create CIFAR100 dataset
        train_dataset = Cifar100(DATA_DIR, train=True, download=download, random_state=RANDOM_STATES[run_i], transform=train_transform)
        test_dataset = Cifar100(DATA_DIR, train=False, download=False, random_state=RANDOM_STATES[run_i], transform=test_transform)
    
        # Subspace of CIFAR100 of 10 classes
        train_dataset.set_classes_batch(train_dataset.batch_splits[split_i]) 
        test_dataset.set_classes_batch([test_dataset.batch_splits[i] for i in range(0, split_i+1)])

        # Define train and validation indices
        train_indices, val_indices = train_dataset.train_val_split(VAL_SIZE, RANDOM_STATES[run_i])

        # Define subsets
        train_subsets[run_i].append(Subset(train_dataset, train_indices))
        val_subsets[run_i].append(Subset(train_dataset, val_indices))
        test_subsets[run_i].append(test_dataset)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to data/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/cifar-100-python.tar.gz to data

# %% [markdown]
# ## Classifiers

# %% [markdown]
# ### K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

class iCaRLwithKNN(iCaRL):
    def classifier_fit(self, train_dataset, **clf_args):
        """Fit classifier on the union of training dataset and exemplars."""

        # Union of training dataset and exemplars
        exemplars_dataset = Exemplars(self.exemplars, self.train_transform)
        train_dataset_with_exemplars = ConcatDataset([exemplars_dataset, train_dataset])

        # Convert dataset to numpy format
        # X contains training samples, y contains labels
        X, y = self.dataset_to_numpy(train_dataset_with_exemplars)

        # Extract features from the training dataset
        X_features = self.extract_features(torch.tensor(X, dtype=torch.float))
        for i in range(X_features.size(0)):
            X_features[i] = X_features[i]/X_features[i].norm()
        X_features = X_features.to('cpu').numpy()

        self.clf = KNeighborsClassifier(clf_args['n_neighbors'])
        self.clf.fit(X_features, y)

    def classifier_predict(self, test_dataset):
        """Predict labels of test_dataset."""

        X_test, y_test = self.dataset_to_numpy(test_dataset)

        # Extract features from the test set
        X_test_features = self.extract_features(torch.tensor(X_test, dtype=torch.float))
        for i in range(X_test_features.size(0)):
            X_test_features[i] = X_test_features[i]/X_test_features[i].norm()
        X_test_features = X_test_features.to('cpu').numpy()
        
        y_pred = self.clf.predict(X_test_features)

        return y_test, y_pred

    def dataset_to_numpy(self, dataset):
        # Preallocate arrays
        X = np.zeros((len(dataset), 3, 32, 32))
        y = np.zeros(len(dataset), dtype=int)

        dataloader = DataLoader(dataset, batch_size=1)

        for idx, (image, labels) in enumerate(dataloader):
            X[idx] = image[0].numpy()
            y[idx] = labels.numpy()[0]

        return X, y

    def test_knn(self, test_dataset, train_dataset):
        """Test the model.

        Args:
            test_dataset: dataset on which to test the network
            train_dataset: training set used to train the last split
        Returns:
            accuracy (float): accuracy of the model on the test set
        """

        self.net.train(False)
        if self.best_net is not None: self.best_net.train(False)  # Set Network to evaluation mode
        if self.old_net is not None: self.old_net.train(False)

        with torch.no_grad():
            self.classifier_fit(train_dataset, n_neighbors=3)
            y_truth, y_pred = self.classifier_predict(test_dataset)

        # Calculate accuracy
        accuracy = accuracy_score(y_truth, y_pred)

        print(f"Test accuracy (iCaRL with KNN): {accuracy} ")

        return accuracy

# %%
LR = 2
MOMENTUM = 0.9
WEIGHT_DECAY = 0.00001
MILESTONES = [49, 63]
GAMMA = 0.2
NUM_EPOCHS = 70
BATCH_SIZE = 128

# %%
logs_icarl = [[] for _ in range(NUM_RUNS)]
logs_icarl_knn = [[] for _ in range(NUM_RUNS)]

for run_i in range(NUM_RUNS):
    net = resnet32()
    icarl_knn = iCaRLwithKNN(DEVICE, net, LR, MOMENTUM, WEIGHT_DECAY, MILESTONES, GAMMA, NUM_EPOCHS, BATCH_SIZE, train_transform, test_transform)

    for split_i in range(10):
        print(f"## Split {split_i} of run {run_i} ##")
        
        train_logs = icarl_knn.incremental_train(split_i, train_subsets[run_i][split_i], val_subsets[run_i][split_i])

        acc, _ = icarl_knn.test(test_subsets[run_i][split_i], train_subsets[run_i][split_i])
        logs_icarl[run_i].append(acc)

        acc = icarl_knn.test_knn(test_subsets[run_i][split_i], train_subsets[run_i][split_i])
        logs_icarl_knn[run_i].append(acc)

# %% [markdown]
# ### Linear SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

class iCaRLwithSVM(iCaRL):
    def classifier_fit(self, train_dataset, **clf_args):
        """Fit classifier on the union of training dataset and exemplars."""

        # Union of training dataset and exemplars
        exemplars_dataset = Exemplars(self.exemplars, self.train_transform)
        train_dataset_with_exemplars = ConcatDataset([exemplars_dataset, train_dataset])

        # Convert dataset to numpy format
        # X contains training samples, y contains labels
        X, y = self.dataset_to_numpy(train_dataset_with_exemplars)

        # Extract features from the training dataset
        X_features = self.extract_features(torch.tensor(X, dtype=torch.float))
        for i in range(X_features.size(0)):
            X_features[i] = X_features[i]/X_features[i].norm()
        X_features = X_features.to('cpu').numpy()

        self.clf = SVC(C=clf_args['C'], kernel=clf_args['kernel'], gamma=clf_args['gamma'])
        self.clf.fit(X_features, y)

    def classifier_predict(self, test_dataset):
        """Predict labels of test_dataset."""

        X_test, y_test = self.dataset_to_numpy(test_dataset)

        # Extract features from the test set
        X_test_features = self.extract_features(torch.tensor(X_test, dtype=torch.float))
        for i in range(X_test_features.size(0)):
            X_test_features[i] = X_test_features[i]/X_test_features[i].norm()
        X_test_features = X_test_features.to('cpu').numpy()
        
        y_pred = self.clf.predict(X_test_features)

        return y_test, y_pred

    def dataset_to_numpy(self, dataset):
        # Preallocate arrays
        X = np.zeros((len(dataset), 3, 32, 32))
        y = np.zeros(len(dataset), dtype=int)

        dataloader = DataLoader(dataset, batch_size=1)

        for idx, (image, labels) in enumerate(dataloader):
            X[idx] = image[0].numpy()
            y[idx] = labels.numpy()[0]

        return X, y

    def test_knn(self, test_dataset, train_dataset):
        """Test the model.

        Args:
            test_dataset: dataset on which to test the network
            train_dataset: training set used to train the last split
        Returns:
            accuracy (float): accuracy of the model on the test set
        """

        self.net.train(False)
        if self.best_net is not None: self.best_net.train(False)  # Set Network to evaluation mode
        if self.old_net is not None: self.old_net.train(False)

        with torch.no_grad():
            self.classifier_fit(train_dataset, C=1, kernel="rbf", gamma="auto")
            y_truth, y_pred = self.classifier_predict(test_dataset)

        # Calculate accuracy
        accuracy = accuracy_score(y_truth, y_pred)

        print(f"Test accuracy (iCaRL with SVC): {accuracy} ")

        return accuracy

# %%
LR = 2
MOMENTUM = 0.9
WEIGHT_DECAY = 0.00001
MILESTONES = [49, 63]
GAMMA = 0.2
NUM_EPOCHS = 70
BATCH_SIZE = 128

# %%
logs_icarl = [[] for _ in range(NUM_RUNS)]
logs_icarl_svm = [[] for _ in range(NUM_RUNS)]

for run_i in range(NUM_RUNS):
    net = resnet32()
    icarl_svm = iCaRLwithSVM(DEVICE, net, LR, MOMENTUM, WEIGHT_DECAY, MILESTONES, GAMMA, NUM_EPOCHS, BATCH_SIZE, train_transform, test_transform)

    for split_i in range(10):
        print(f"## Split {split_i} of run {run_i} ##")
        
        train_logs = icarl_svm.incremental_train(split_i, train_subsets[run_i][split_i], val_subsets[run_i][split_i])

        acc, _ = icarl_svm.test(test_subsets[run_i][split_i], train_subsets[run_i][split_i])
        logs_icarl[run_i].append(acc)

        acc = icarl_svm.test_knn(test_subsets[run_i][split_i], train_subsets[run_i][split_i])
        logs_icarl_svm[run_i].append(acc)

# %%
print(logs_icarl)
print(logs_icarl_svm)from sklearn.svm import SVC

# %% [markdown]
# ### All classifiers

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
LR = 2
MOMENTUM = 0.9
WEIGHT_DECAY = 0.00001
MILESTONES = [49, 63]
GAMMA = 0.2
NUM_EPOCHS = 70
BATCH_SIZE = 64

# %%
class iCaRLwithCLFS(iCaRL):
    def classifier_fit(self, train_dataset, split):
        """Fit classifier on the union of training dataset and exemplars."""

        # Union of training dataset and exemplars
        exemplars_dataset = Exemplars(self.exemplars, self.train_transform)
        train_dataset_with_exemplars = ConcatDataset([exemplars_dataset, train_dataset])

        # Convert dataset to numpy format
        # X contains training samples, y contains labels
        X, y = self.dataset_to_numpy(train_dataset_with_exemplars)

        # Extract features from the training dataset
        X_features = self.extract_features(torch.tensor(X, dtype=torch.float))
        for i in range(X_features.size(0)):
            X_features[i] = X_features[i]/X_features[i].norm()
        X_features = X_features.to('cpu').numpy()

        param_grid1 = { 
          'n_estimators': [100, 200, 500],
          'max_features': ['sqrt', 'log2'],
          'max_depth' : [5,6,7],
          'criterion' :['gini', 'entropy']
        }

        param_grid2 = {
            'n_neighbors': [3, 5, 7, 9],
            'leaf_size': [10, 30, 100]
        }
        param_grid3 = {
            'kernel' : ['linear', 'rbf', 'sigmoid'],
            'C' : [0.01, 0.1, 1, 10],
            'gamma' : [1, 0.1, 0.01, 0.001]
        }

        self.clf1 = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid1, cv=3, refit=True)
        self.clf2 = GridSearchCV(estimator=KNeighborsClassifier(), param_grid=param_grid2, cv=3, refit=True)
        self.clf3 = GridSearchCV(estimator=SVC(), param_grid=param_grid3, cv=3, refit=True)
       

        print('gridsearch rfc . . .')
        self.clf1.fit(X_features, y)
        print('gridsearch knn . . .')
        self.clf2.fit(X_features, y)
        print('gridsearch svc . . .')
        self.clf3.fit(X_features, y)
        print('gridsearch done.')

        with open('./params.txt', 'a+') as writefile:
          writefile.write(f"split {split}\n")
          writefile.write(f"rfc best parameters:\n n_estimtors: {self.clf1.best_params_['n_estimators']}\n max_features : {self.clf1.best_params_['max_features']}\n max_depth : {self.clf1.best_params_['max_depth']}\n criterion : {self.clf1.best_params_['criterion']}\n")
          writefile.write(f"knn best parameters:\n knn__n_neighbors : {self.clf2.best_params_['n_neighbors']}\n leaf_size : {self.clf2.best_params_['leaf_size']}\n")
          writefile.write(f"svc best parameters:\n kernel : {self.clf3.best_params_['kernel']}\n C : {self.clf3.best_params_['C']}\n gamma : {self.clf3.best_params_['gamma']}\n\n")


        


    def classifier_predict(self, test_dataset):
        """Predict labels of test_dataset."""

        X_test, y_test = self.dataset_to_numpy(test_dataset)

        # Extract features from the test set
        X_test_features = self.extract_features(torch.tensor(X_test, dtype=torch.float))
        for i in range(X_test_features.size(0)):
            X_test_features[i] = X_test_features[i]/X_test_features[i].norm()
        X_test_features = X_test_features.to('cpu').numpy()
        
        y_pred1 = self.clf1.predict(X_test_features)
        y_pred2 = self.clf2.predict(X_test_features)
        y_pred3 = self.clf3.predict(X_test_features)

        return y_test, y_pred1, y_pred2, y_pred3

    def dataset_to_numpy(self, dataset):
        # Preallocate arrays
        X = np.zeros((len(dataset), 3, 32, 32))
        y = np.zeros(len(dataset), dtype=int)

        dataloader = DataLoader(dataset, batch_size=1)

        for idx, (image, labels) in enumerate(dataloader):
            X[idx] = image[0].numpy()
            y[idx] = labels.numpy()[0]

        return X, y

    def test_classifiers(self, test_dataset, train_dataset, split):
        """Test the model.

        Args:
            test_dataset: dataset on which to test the network
            train_dataset: training set used to train the last split
        Returns:
            accuracy (float): accuracy of the model on the test set
        """

        self.net.train(False)
        if self.best_net is not None: self.best_net.train(False)  # Set Network to evaluation mode
        if self.old_net is not None: self.old_net.train(False)

        with torch.no_grad():
            self.classifier_fit(train_dataset, split)
            y_truth, y_pred1, y_pred2, y_pred3 = self.classifier_predict(test_dataset)

        # Calculate accuracy
        accuracy1 = accuracy_score(y_truth, y_pred1)
        accuracy2 = accuracy_score(y_truth, y_pred2)
        accuracy3 = accuracy_score(y_truth, y_pred3)

        print(f"Test accuracy (iCaRL with RFC): {accuracy1} ")
        print(f"Test accuracy (iCaRL with KNN): {accuracy2} ")
        print(f"Test accuracy (iCaRL with SVC): {accuracy3} ")

        return accuracy1, accuracy2, accuracy3

# %%
from google.colab import files
logs_icarl = [[] for _ in range(NUM_RUNS)]
logs_icarl_rfc = [[] for _ in range(NUM_RUNS)]
logs_icarl_knn = [[] for _ in range(NUM_RUNS)]
logs_icarl_svc = [[] for _ in range(NUM_RUNS)]

for run_i in range(NUM_RUNS):
    net = resnet32()

    icarl_CLFS = iCaRLwithCLFS(DEVICE, net, LR, MOMENTUM, WEIGHT_DECAY, MILESTONES, GAMMA, NUM_EPOCHS, BATCH_SIZE, train_transform, test_transform)
    
    for split_i in range(10):
        print(f"## Split {split_i} of run {run_i} ##")
        
        train_logs = icarl_CLFS.incremental_train(split_i, train_subsets[run_i][split_i], val_subsets[run_i][split_i])

        acc, _ = icarl_CLFS.test(test_subsets[run_i][split_i], train_subsets[run_i][split_i])
        logs_icarl[run_i].append(acc)

        acc1, acc2, acc3 = icarl_CLFS.test_classifiers(test_subsets[run_i][split_i], train_subsets[run_i][split_i], split_i)
        logs_icarl_rfc[run_i].append(acc1)
        logs_icarl_knn[run_i].append(acc2)
        logs_icarl_svc[run_i].append(acc3)

        with open('./logs.txt', 'a+') as writefile:
          writefile.write(f"split : {split_i} \n")
          writefile.write(f" accuracy iCaRL : {acc} \n")
          writefile.write(f" accuracy rfc : {acc1} \n")
          writefile.write(f" accuracy knn : {acc2} \n")
          writefile.write(f" accuracy svc : {acc3} \n\n")
        
        
        #files.download('params.txt')
        #files.download('logs.txt')
# Out:
# ## Split 0 of run 0 ##
# Length of exemplars set: 0
# Epoch: 1, LR: [2]
# Train loss: 0.38076903309140886, Train accuracy: 0.11272321428571429
# Validation loss: 0.31493704659598215, Validation accuracy: 0.15625
# Epoch: 2, LR: [2]
# Train loss: 0.31688896204744066, Train accuracy: 0.146875
# Validation loss: 0.3190891913005284, Validation accuracy: 0.15178571428571427
# Epoch: 3, LR: [2]
# Train loss: 0.3145806734051023, Train accuracy: 0.15647321428571428
# Validation loss: 0.3096286654472351, Validation accuracy: 0.22098214285714285
# Epoch: 4, LR: [2]
# Train loss: 0.3120531861271177, Train accuracy: 0.1703125
# Validation loss: 0.31103040490831646, Validation accuracy: 0.16517857142857142
# Epoch: 5, LR: [2]
# Train loss: 0.30944669800145286, Train accuracy: 0.18325892857142856
# Validation loss: 0.3067276562963213, Validation accuracy: 0.21651785714285715
# Epoch: 6, LR: [2]
# Train loss: 0.3025490760803223, Train accuracy: 0.21808035714285715
# Validation loss: 0.29939849036080496, Validation accuracy: 0.19866071428571427
# Epoch: 7, LR: [2]
# Train loss: 0.2986154156071799, Train accuracy: 0.225
# Validation loss: 0.30798472676958355, Validation accuracy: 0.23214285714285715
# Epoch: 8, LR: [2]
# Train loss: 0.2948862101350512, Train accuracy: 0.2520089285714286
# Validation loss: 0.27970617158072336, Validation accuracy: 0.28794642857142855
# Epoch: 9, LR: [2]
# Train loss: 0.2882513267653329, Train accuracy: 0.28125
# Validation loss: 0.2731183341571263, Validation accuracy: 0.3169642857142857
# Epoch: 10, LR: [2]
# Train loss: 0.2843727075627872, Train accuracy: 0.3044642857142857
# Validation loss: 0.29359576957566397, Validation accuracy: 0.25223214285714285
# Epoch: 11, LR: [2]
# Train loss: 0.2786339502249445, Train accuracy: 0.3453125
# Validation loss: 0.27508040836879183, Validation accuracy: 0.3482142857142857
# Epoch: 12, LR: [2]
# Train loss: 0.2677957279341561, Train accuracy: 0.36964285714285716
# Validation loss: 0.26409532342638287, Validation accuracy: 0.3638392857142857
# Epoch: 13, LR: [2]
# Train loss: 0.25964206010103225, Train accuracy: 0.39888392857142857
# Validation loss: 0.27106809828962597, Validation accuracy: 0.39285714285714285
# Epoch: 14, LR: [2]
# Train loss: 0.24710184399570737, Train accuracy: 0.43794642857142857
# Validation loss: 0.29975055158138275, Validation accuracy: 0.41517857142857145
# Epoch: 15, LR: [2]
# Train loss: 0.23727813128914152, Train accuracy: 0.47410714285714284
# Validation loss: 0.2337063274213246, Validation accuracy: 0.49776785714285715
# Epoch: 16, LR: [2]
# Train loss: 0.22825791133301598, Train accuracy: 0.49754464285714284
# Validation loss: 0.23333888394492014, Validation accuracy: 0.47767857142857145
# Epoch: 17, LR: [2]
# Train loss: 0.21823401429823466, Train accuracy: 0.5332589285714285
# Validation loss: 0.23896165830748423, Validation accuracy: 0.4955357142857143
# Epoch: 18, LR: [2]
# Train loss: 0.21222473915134157, Train accuracy: 0.5435267857142857
# Validation loss: 0.2109257983309882, Validation accuracy: 0.5424107142857143
# Epoch: 19, LR: [2]
# Train loss: 0.20358085376875742, Train accuracy: 0.5638392857142858
# Validation loss: 0.2240144440105983, Validation accuracy: 0.5223214285714286
# Epoch: 20, LR: [2]
# Train loss: 0.199674676997321, Train accuracy: 0.5669642857142857
# Validation loss: 0.24769361104284013, Validation accuracy: 0.46875
# Epoch: 21, LR: [2]
# Train loss: 0.19099062319312776, Train accuracy: 0.5970982142857143
# Validation loss: 0.19354007499558584, Validation accuracy: 0.5848214285714286
# Epoch: 22, LR: [2]
# Train loss: 0.17645769332136427, Train accuracy: 0.6225446428571428
# Validation loss: 0.259048336318561, Validation accuracy: 0.4419642857142857
# Epoch: 23, LR: [2]
# Train loss: 0.16605948358774186, Train accuracy: 0.6457589285714286
# Validation loss: 0.17479514011314937, Validation accuracy: 0.6540178571428571
# Epoch: 24, LR: [2]
# Train loss: 0.1590018223438944, Train accuracy: 0.6712053571428571
# Validation loss: 0.21321289454187667, Validation accuracy: 0.5758928571428571
# Epoch: 25, LR: [2]
# Train loss: 0.15092550069093705, Train accuracy: 0.6883928571428571
# Validation loss: 0.152855213199343, Validation accuracy: 0.6785714285714286
# Epoch: 26, LR: [2]
# Train loss: 0.1364303212080683, Train accuracy: 0.7243303571428571
# Validation loss: 0.1599964393036706, Validation accuracy: 0.6607142857142857
# Epoch: 27, LR: [2]
# Train loss: 0.1363967934889453, Train accuracy: 0.7154017857142857
# Validation loss: 0.16156799026897975, Validation accuracy: 0.6785714285714286
# Epoch: 28, LR: [2]
# Train loss: 0.133117327945573, Train accuracy: 0.7274553571428571
# Validation loss: 0.1586654516203063, Validation accuracy: 0.6830357142857143
# Epoch: 29, LR: [2]
# Train loss: 0.12494805710656302, Train accuracy: 0.7488839285714286
# Validation loss: 0.14948889187404088, Validation accuracy: 0.7120535714285714
# Epoch: 30, LR: [2]
# Train loss: 0.12061978152820042, Train accuracy: 0.7607142857142857
# Validation loss: 0.11457931463207517, Validation accuracy: 0.7678571428571429
# Epoch: 31, LR: [2]
# Train loss: 0.1122496454843453, Train accuracy: 0.7770089285714286
# Validation loss: 0.20400983733790262, Validation accuracy: 0.6183035714285714
# Epoch: 32, LR: [2]
# Train loss: 0.11425093188881874, Train accuracy: 0.7765625
# Validation loss: 0.11457296780177526, Validation accuracy: 0.7790178571428571
# Epoch: 33, LR: [2]
# Train loss: 0.10770425849727222, Train accuracy: 0.796875
# Validation loss: 0.11524661523955208, Validation accuracy: 0.7611607142857143
# Epoch: 34, LR: [2]
# Train loss: 0.10684671029448509, Train accuracy: 0.7910714285714285
# Validation loss: 0.14312101900577545, Validation accuracy: 0.7165178571428571
# Epoch: 35, LR: [2]
# Train loss: 0.10485695898532868, Train accuracy: 0.7953125
# Validation loss: 0.1163622470838683, Validation accuracy: 0.7790178571428571
# Epoch: 36, LR: [2]
# Train loss: 0.10005246102809906, Train accuracy: 0.8035714285714286
# Validation loss: 0.13484917474644526, Validation accuracy: 0.7388392857142857
# Epoch: 37, LR: [2]
# Train loss: 0.09863043007041727, Train accuracy: 0.8111607142857142
# Validation loss: 0.15536038045372283, Validation accuracy: 0.7075892857142857
# Epoch: 38, LR: [2]
# Train loss: 0.09435467975480216, Train accuracy: 0.8212053571428571
# Validation loss: 0.11064875551632472, Validation accuracy: 0.7991071428571429
# Epoch: 39, LR: [2]
# Train loss: 0.08614456110766956, Train accuracy: 0.8388392857142857
# Validation loss: 0.10866139296974454, Validation accuracy: 0.7745535714285714
# Epoch: 40, LR: [2]
# Train loss: 0.0883633989840746, Train accuracy: 0.8310267857142857
# Validation loss: 0.103685876088483, Validation accuracy: 0.78125
# Epoch: 41, LR: [2]
# Train loss: 0.08979274827454771, Train accuracy: 0.8290178571428571
# Validation loss: 0.1095712695802961, Validation accuracy: 0.796875
# Epoch: 42, LR: [2]
# Train loss: 0.08635604998895101, Train accuracy: 0.8350446428571429
# Validation loss: 0.12048702899898801, Validation accuracy: 0.7723214285714286
# Epoch: 43, LR: [2]
# Train loss: 0.08193993350224836, Train accuracy: 0.8419642857142857
# Validation loss: 0.13243199778454645, Validation accuracy: 0.7633928571428571
# Epoch: 44, LR: [2]
# Train loss: 0.08235964961349965, Train accuracy: 0.8462053571428572
# Validation loss: 0.16250023352248327, Validation accuracy: 0.6852678571428571
# Epoch: 45, LR: [2]
# Train loss: 0.07777202395456177, Train accuracy: 0.8564732142857143
# Validation loss: 0.12293787726334163, Validation accuracy: 0.7924107142857143
# Epoch: 46, LR: [2]
# Train loss: 0.07316279209085873, Train accuracy: 0.8662946428571429
# Validation loss: 0.10729832627943584, Validation accuracy: 0.8058035714285714
# Epoch: 47, LR: [2]
# Train loss: 0.0740363563810076, Train accuracy: 0.8620535714285714
# Validation loss: 0.09992130207163948, Validation accuracy: 0.8147321428571429
# Epoch: 48, LR: [2]
# Train loss: 0.07253104078450373, Train accuracy: 0.8674107142857143
# Validation loss: 0.12898401490279607, Validation accuracy: 0.7924107142857143
# Epoch: 49, LR: [2]
# Train loss: 0.06956048448170934, Train accuracy: 0.8703125
# Validation loss: 0.09825954266956874, Validation accuracy: 0.8236607142857143
# Epoch: 50, LR: [0.4]
# Train loss: 0.05147589075246028, Train accuracy: 0.9080357142857143
# Validation loss: 0.08245336264371872, Validation accuracy: 0.8571428571428571
# Epoch: 51, LR: [0.4]
# Train loss: 0.04141290477876152, Train accuracy: 0.9247767857142857
# Validation loss: 0.06393371256334442, Validation accuracy: 0.8772321428571429
# Epoch: 52, LR: [0.4]
# Train loss: 0.04199667197785207, Train accuracy: 0.9261160714285714
# Validation loss: 0.06492616768394198, Validation accuracy: 0.8794642857142857
# Epoch: 53, LR: [0.4]
# Train loss: 0.03657599766073483, Train accuracy: 0.9383928571428571
# Validation loss: 0.07261478209069797, Validation accuracy: 0.8772321428571429
# Epoch: 54, LR: [0.4]
# Train loss: 0.03631498562172055, Train accuracy: 0.9381696428571429
# Validation loss: 0.07604675314256124, Validation accuracy: 0.8571428571428571
# Epoch: 55, LR: [0.4]
# Train loss: 0.033051850460469726, Train accuracy: 0.9421875
# Validation loss: 0.06772571908576148, Validation accuracy: 0.8861607142857143
# Epoch: 56, LR: [0.4]
# Train loss: 0.03467940754656281, Train accuracy: 0.9401785714285714
# Validation loss: 0.07189111092260905, Validation accuracy: 0.8883928571428571
# Epoch: 57, LR: [0.4]
# Train loss: 0.033359377764697586, Train accuracy: 0.9424107142857143
# Validation loss: 0.06708717346191406, Validation accuracy: 0.8950892857142857
# Epoch: 58, LR: [0.4]
# Train loss: 0.02958559263497591, Train accuracy: 0.9482142857142857
# Validation loss: 0.06719206007463592, Validation accuracy: 0.8839285714285714
# Epoch: 59, LR: [0.4]
# Train loss: 0.0289726001609649, Train accuracy: 0.9493303571428572
# Validation loss: 0.06928793607013566, Validation accuracy: 0.8683035714285714
# Epoch: 60, LR: [0.4]
# Train loss: 0.028178255898611886, Train accuracy: 0.9517857142857142
# Validation loss: 0.07723028425659452, Validation accuracy: 0.8861607142857143
# Epoch: 61, LR: [0.4]
# Train loss: 0.02730166857529964, Train accuracy: 0.9549107142857143
# Validation loss: 0.07362989921654974, Validation accuracy: 0.8772321428571429
# Epoch: 62, LR: [0.4]
# Train loss: 0.026316017817173687, Train accuracy: 0.9542410714285714
# Validation loss: 0.08569021735872541, Validation accuracy: 0.8839285714285714
# Epoch: 63, LR: [0.4]
# Train loss: 0.025458678802741424, Train accuracy: 0.9575892857142857
# Validation loss: 0.07778792987976756, Validation accuracy: 0.8928571428571429
# Epoch: 64, LR: [0.08000000000000002]
# Train loss: 0.02299671182408929, Train accuracy: 0.9611607142857143
# Validation loss: 0.06396298536232539, Validation accuracy: 0.9084821428571429
# Epoch: 65, LR: [0.08000000000000002]
# Train loss: 0.021779141136045968, Train accuracy: 0.9649553571428572
# Validation loss: 0.0658785408096654, Validation accuracy: 0.8861607142857143
# Epoch: 66, LR: [0.08000000000000002]
# Train loss: 0.020363265774878007, Train accuracy: 0.9712053571428572
# Validation loss: 0.07830413430929184, Validation accuracy: 0.8772321428571429
# Epoch: 67, LR: [0.08000000000000002]
# Train loss: 0.018708572217396326, Train accuracy: 0.971875
# Validation loss: 0.06568390769617898, Validation accuracy: 0.8950892857142857
# Epoch: 68, LR: [0.08000000000000002]
# Train loss: 0.019333465098004255, Train accuracy: 0.971875
# Validation loss: 0.07228528388908931, Validation accuracy: 0.890625
# Epoch: 69, LR: [0.08000000000000002]
# Train loss: 0.019035110622644423, Train accuracy: 0.9727678571428572
# Validation loss: 0.06161448998110635, Validation accuracy: 0.9084821428571429
# Epoch: 70, LR: [0.08000000000000002]
# Train loss: 0.018032215725231383, Train accuracy: 0.9720982142857143
# Validation loss: 0.07130171252148491, Validation accuracy: 0.8995535714285714
# Target number of exemplars per class: 200
# Target total number of exemplars: 2000
# Randomly extracting exemplars from class 0 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 200 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 200 exemplars.
# Computing mean of exemplars... done
# Test accuracy (iCaRL): 0.876 (exemplars and training data)
# gridsearch rfc . . .
# gridsearch knn . . .
# gridsearch svc . . .
# gridsearch done.
# Test accuracy (iCaRL with RFC): 0.874
# Test accuracy (iCaRL with KNN): 0.881
# Test accuracy (iCaRL with SVC): 0.883
# ## Split 1 of run 0 ##
# Length of exemplars set: 2000
# Epoch: 1, LR: [2]
# Train loss: 0.164660180116644, Train accuracy: 0.31636757425742573
# Validation loss: 0.2053064320768629, Validation accuracy: 0.10044642857142858
# Epoch: 2, LR: [2]
# Train loss: 0.1344596581293805, Train accuracy: 0.40547648514851486
# Validation loss: 0.2059911744935172, Validation accuracy: 0.21428571428571427
# Epoch: 3, LR: [2]
# Train loss: 0.12819937874775122, Train accuracy: 0.4586943069306931
# Validation loss: 0.2026623295886176, Validation accuracy: 0.28125
# Epoch: 4, LR: [2]
# Train loss: 0.11882887367564852, Train accuracy: 0.5083539603960396
# Validation loss: 0.20050238285745894, Validation accuracy: 0.296875
# Epoch: 5, LR: [2]
# Train loss: 0.11803122292650808, Train accuracy: 0.5335705445544554
# Validation loss: 0.18476225648607528, Validation accuracy: 0.3482142857142857
# Epoch: 6, LR: [2]
# Train loss: 0.11404246903292023, Train accuracy: 0.5601794554455446
# Validation loss: 0.18568563887051173, Validation accuracy: 0.40848214285714285
# Epoch: 7, LR: [2]
# Train loss: 0.10919120679102322, Train accuracy: 0.5866336633663366
# Validation loss: 0.17417097091674805, Validation accuracy: 0.41294642857142855
# Epoch: 8, LR: [2]
# Train loss: 0.10815813075197805, Train accuracy: 0.6025680693069307
# Validation loss: 0.18711433240345546, Validation accuracy: 0.41294642857142855
# Epoch: 9, LR: [2]
# Train loss: 0.10624852547846218, Train accuracy: 0.6206683168316832
# Validation loss: 0.18246866975511825, Validation accuracy: 0.4174107142857143
# Epoch: 10, LR: [2]
# Train loss: 0.10359649950324899, Train accuracy: 0.6313428217821783
# Validation loss: 0.18206055462360382, Validation accuracy: 0.46875
# Epoch: 11, LR: [2]
# Train loss: 0.10221891658435954, Train accuracy: 0.6400061881188119
# Validation loss: 0.17000693082809448, Validation accuracy: 0.42410714285714285
# Epoch: 12, LR: [2]
# Train loss: 0.0999275009230812, Train accuracy: 0.6577970297029703
# Validation loss: 0.1888252411569868, Validation accuracy: 0.4263392857142857
# Epoch: 13, LR: [2]
# Train loss: 0.09945611345886003, Train accuracy: 0.6582611386138614
# Validation loss: 0.15806922955172403, Validation accuracy: 0.5558035714285714
# Epoch: 14, LR: [2]
# Train loss: 0.10048318868226344, Train accuracy: 0.6672339108910891
# Validation loss: 0.16723931900092534, Validation accuracy: 0.48214285714285715
# Epoch: 15, LR: [2]
# Train loss: 0.09798662630048129, Train accuracy: 0.6762066831683168
# Validation loss: 0.15962295021329606, Validation accuracy: 0.5267857142857143
# Epoch: 16, LR: [2]
# Train loss: 0.0970246563158413, Train accuracy: 0.6845606435643564
# Validation loss: 0.15474772666181838, Validation accuracy: 0.5133928571428571
# Epoch: 17, LR: [2]
# Train loss: 0.09505499670706173, Train accuracy: 0.687809405940594
# Validation loss: 0.19430171166147506, Validation accuracy: 0.5022321428571429
# Epoch: 18, LR: [2]
# Train loss: 0.09584418507200657, Train accuracy: 0.682240099009901
# Validation loss: 0.14751232521874563, Validation accuracy: 0.5491071428571429
# Epoch: 19, LR: [2]
# Train loss: 0.0944931961522244, Train accuracy: 0.7006497524752475
# Validation loss: 0.16445256769657135, Validation accuracy: 0.546875
# Epoch: 20, LR: [2]
# Train loss: 0.0930528180433972, Train accuracy: 0.7032797029702971
# Validation loss: 0.1674607310976301, Validation accuracy: 0.5245535714285714
# Epoch: 21, LR: [2]
# Train loss: 0.09194521871533724, Train accuracy: 0.7116336633663366
# Validation loss: 0.1629177119050707, Validation accuracy: 0.47767857142857145
# Epoch: 22, LR: [2]
# Train loss: 0.0915338325470981, Train accuracy: 0.7212252475247525
# Validation loss: 0.15102623722382955, Validation accuracy: 0.5691964285714286
# Epoch: 23, LR: [2]
# Train loss: 0.09032307196371626, Train accuracy: 0.7232363861386139
# Validation loss: 0.16444686480930873, Validation accuracy: 0.5089285714285714
# Epoch: 24, LR: [2]
# Train loss: 0.09057907066722908, Train accuracy: 0.7216893564356436
# Validation loss: 0.15760939036096847, Validation accuracy: 0.5200892857142857
# Epoch: 25, LR: [2]
# Train loss: 0.0896180457260349, Train accuracy: 0.7266398514851485
# Validation loss: 0.16216643154621124, Validation accuracy: 0.5357142857142857
# Epoch: 26, LR: [2]
# Train loss: 0.09023271102716426, Train accuracy: 0.7254022277227723
# Validation loss: 0.17602022205080306, Validation accuracy: 0.5446428571428571
# Epoch: 27, LR: [2]
# Train loss: 0.08791023743624735, Train accuracy: 0.7303527227722773
# Validation loss: 0.19033639984471457, Validation accuracy: 0.5022321428571429
# Epoch: 28, LR: [2]
# Train loss: 0.08786894369981077, Train accuracy: 0.7408725247524752
# Validation loss: 0.164432555437088, Validation accuracy: 0.5714285714285714
# Epoch: 29, LR: [2]
# Train loss: 0.08830807062954006, Train accuracy: 0.7390160891089109
# Validation loss: 0.15893627277442388, Validation accuracy: 0.5736607142857143
# Epoch: 30, LR: [2]
# Train loss: 0.086303674864887, Train accuracy: 0.7472153465346535
# Validation loss: 0.16767809007849013, Validation accuracy: 0.59375
# Epoch: 31, LR: [2]
# Train loss: 0.08604256661221532, Train accuracy: 0.7459777227722773
# Validation loss: 0.18501007982662745, Validation accuracy: 0.5424107142857143
# Epoch: 32, LR: [2]
# Train loss: 0.08759509344207178, Train accuracy: 0.755105198019802
# Validation loss: 0.1642365391765322, Validation accuracy: 0.5870535714285714
# Epoch: 33, LR: [2]
# Train loss: 0.08450270363009803, Train accuracy: 0.7626856435643564
# Validation loss: 0.16679627767630986, Validation accuracy: 0.5535714285714286
# Epoch: 34, LR: [2]
# Train loss: 0.08303954869066135, Train accuracy: 0.7667079207920792
# Validation loss: 0.1529059112071991, Validation accuracy: 0.5915178571428571
# Epoch: 35, LR: [2]
# Train loss: 0.08348291142299624, Train accuracy: 0.7704207920792079
# Validation loss: 0.17175134590693883, Validation accuracy: 0.5870535714285714
# Epoch: 36, LR: [2]
# Train loss: 0.0835660548124573, Train accuracy: 0.7688737623762376
# Validation loss: 0.1990755306822913, Validation accuracy: 0.49107142857142855
# Epoch: 37, LR: [2]
# Train loss: 0.0821337886892333, Train accuracy: 0.7770730198019802
# Validation loss: 0.18441661979470933, Validation accuracy: 0.5424107142857143
# Epoch: 38, LR: [2]
# Train loss: 0.08212252488673323, Train accuracy: 0.7687190594059405
# Validation loss: 0.21247066770281112, Validation accuracy: 0.5401785714285714
# Epoch: 39, LR: [2]
# Train loss: 0.08339112724112992, Train accuracy: 0.7701113861386139
# Validation loss: 0.17152038429464614, Validation accuracy: 0.5758928571428571
# Epoch: 40, LR: [2]
# Train loss: 0.08295552045254424, Train accuracy: 0.7650061881188119
# Validation loss: 0.15428730845451355, Validation accuracy: 0.609375
# Epoch: 41, LR: [2]
# Train loss: 0.08331371017611854, Train accuracy: 0.7679455445544554
# Validation loss: 0.20634800621441432, Validation accuracy: 0.5111607142857143
# Epoch: 42, LR: [2]
# Train loss: 0.0827022905987088, Train accuracy: 0.7753712871287128
# Validation loss: 0.188502379826137, Validation accuracy: 0.5044642857142857
# Epoch: 43, LR: [2]
# Train loss: 0.08103273524948866, Train accuracy: 0.7790841584158416
# Validation loss: 0.1630102140562875, Validation accuracy: 0.5825892857142857
# Epoch: 44, LR: [2]
# Train loss: 0.0781766243721589, Train accuracy: 0.7824876237623762
# Validation loss: 0.17775323774133409, Validation accuracy: 0.5870535714285714
# Epoch: 45, LR: [2]
# Train loss: 0.07977382307595546, Train accuracy: 0.7920792079207921
# Validation loss: 0.1713316994053977, Validation accuracy: 0.5825892857142857
# Epoch: 46, LR: [2]
# Train loss: 0.08033682962897981, Train accuracy: 0.7922339108910891
# Validation loss: 0.16854039473193033, Validation accuracy: 0.625
# Epoch: 47, LR: [2]
# Train loss: 0.07983545143858041, Train accuracy: 0.7905321782178217
# Validation loss: 0.17151237385613577, Validation accuracy: 0.640625
# Epoch: 48, LR: [2]
# Train loss: 0.08000203354818987, Train accuracy: 0.7908415841584159
# Validation loss: 0.18793422196592605, Validation accuracy: 0.5513392857142857
# Epoch: 49, LR: [2]
# Train loss: 0.0804475300604164, Train accuracy: 0.7988861386138614
# Validation loss: 0.1550226637295314, Validation accuracy: 0.5870535714285714
# Epoch: 50, LR: [0.4]
# Train loss: 0.0663089017835584, Train accuracy: 0.8400371287128713
# Validation loss: 0.15050276901040757, Validation accuracy: 0.65625
# Epoch: 51, LR: [0.4]
# Train loss: 0.062084080079699504, Train accuracy: 0.8612314356435643
# Validation loss: 0.14928682787077768, Validation accuracy: 0.6495535714285714
# Epoch: 52, LR: [0.4]
# Train loss: 0.059988780408212455, Train accuracy: 0.8722153465346535
# Validation loss: 0.14985270585332597, Validation accuracy: 0.6674107142857143
# Epoch: 53, LR: [0.4]
# Train loss: 0.058957620311786633, Train accuracy: 0.8793316831683168
# Validation loss: 0.15841940896851675, Validation accuracy: 0.6808035714285714
# Epoch: 54, LR: [0.4]
# Train loss: 0.05824259229668296, Train accuracy: 0.8889232673267327
# Validation loss: 0.1590755017740386, Validation accuracy: 0.6495535714285714
# Epoch: 55, LR: [0.4]
# Train loss: 0.05724539028683511, Train accuracy: 0.885365099009901
# Validation loss: 0.17054217840944016, Validation accuracy: 0.640625
# Epoch: 56, LR: [0.4]
# Train loss: 0.056565042585134506, Train accuracy: 0.8876856435643564
# Validation loss: 0.15368472465447017, Validation accuracy: 0.6875
# Epoch: 57, LR: [0.4]
# Train loss: 0.056593654179337004, Train accuracy: 0.8935643564356436
# Validation loss: 0.1624698085444314, Validation accuracy: 0.6540178571428571
# Epoch: 58, LR: [0.4]
# Train loss: 0.05577101097396105, Train accuracy: 0.8940284653465347
# Validation loss: 0.1612598385129656, Validation accuracy: 0.6875
# Epoch: 59, LR: [0.4]
# Train loss: 0.055450127745913985, Train accuracy: 0.8974319306930693
# Validation loss: 0.16136525571346283, Validation accuracy: 0.6986607142857143
# Epoch: 60, LR: [0.4]
# Train loss: 0.05605385924624925, Train accuracy: 0.8997524752475248
# Validation loss: 0.16555352296148027, Validation accuracy: 0.6763392857142857
# Epoch: 61, LR: [0.4]
# Train loss: 0.055102085233619896, Train accuracy: 0.9050123762376238
# Validation loss: 0.16565644528184617, Validation accuracy: 0.6852678571428571
# Epoch: 62, LR: [0.4]
# Train loss: 0.05587883832136003, Train accuracy: 0.905940594059406
# Validation loss: 0.16821383791310446, Validation accuracy: 0.6629464285714286
# Epoch: 63, LR: [0.4]
# Train loss: 0.05487161133401465, Train accuracy: 0.9082611386138614
# Validation loss: 0.16095955031258719, Validation accuracy: 0.7008928571428571
# Epoch: 64, LR: [0.08000000000000002]
# Train loss: 0.05337463780352385, Train accuracy: 0.9110457920792079
# Validation loss: 0.16877334671361105, Validation accuracy: 0.6696428571428571
# Epoch: 65, LR: [0.08000000000000002]
# Train loss: 0.052696776161394496, Train accuracy: 0.9150680693069307
# Validation loss: 0.16636091044970922, Validation accuracy: 0.6785714285714286
# Epoch: 66, LR: [0.08000000000000002]
# Train loss: 0.05276809466799887, Train accuracy: 0.9158415841584159
# Validation loss: 0.1693854747073991, Validation accuracy: 0.6741071428571429
# Epoch: 67, LR: [0.08000000000000002]
# Train loss: 0.052179223350664175, Train accuracy: 0.9161509900990099
# Validation loss: 0.1649154850414821, Validation accuracy: 0.7008928571428571
# Epoch: 68, LR: [0.08000000000000002]
# Train loss: 0.052447922454021946, Train accuracy: 0.9152227722772277
# Validation loss: 0.16874519203390395, Validation accuracy: 0.6696428571428571
# Epoch: 69, LR: [0.08000000000000002]
# Train loss: 0.05212907603766659, Train accuracy: 0.9214108910891089
# Validation loss: 0.16646108031272888, Validation accuracy: 0.6830357142857143
# Epoch: 70, LR: [0.08000000000000002]
# Train loss: 0.0525208944362579, Train accuracy: 0.9161509900990099
# Validation loss: 0.16659573572022573, Validation accuracy: 0.6651785714285714
# Target number of exemplars per class: 100
# Target total number of exemplars: 2000
# Randomly extracting exemplars from class 0 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 100 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 100 exemplars.
# Computing mean of exemplars... done
# Test accuracy (iCaRL): 0.795 (exemplars and training data)
# gridsearch rfc . . .
# gridsearch knn . . .
# gridsearch svc . . .
# gridsearch done.
# Test accuracy (iCaRL with RFC): 0.7305
# Test accuracy (iCaRL with KNN): 0.7825
# Test accuracy (iCaRL with SVC): 0.7905
# ## Split 2 of run 0 ##
# Length of exemplars set: 2000
# Epoch: 1, LR: [2]
# Train loss: 0.14251162015860624, Train accuracy: 0.2943997524752475
# Validation loss: 0.16847694771630423, Validation accuracy: 0.05133928571428571
# Epoch: 2, LR: [2]
# Train loss: 0.12299770065168343, Train accuracy: 0.36803836633663367
# Validation loss: 0.1494853858436857, Validation accuracy: 0.19419642857142858
# Epoch: 3, LR: [2]
# Train loss: 0.11825694490482311, Train accuracy: 0.4280631188118812
# Validation loss: 0.1405640265771321, Validation accuracy: 0.26785714285714285
# Epoch: 4, LR: [2]
# Train loss: 0.1152025039243226, Train accuracy: 0.47633044554455445
# Validation loss: 0.14064070795263564, Validation accuracy: 0.23660714285714285
# Epoch: 5, LR: [2]
# Train loss: 0.11276454744067523, Train accuracy: 0.49149133663366334
# Validation loss: 0.13118701108864375, Validation accuracy: 0.35044642857142855
# Epoch: 6, LR: [2]
# Train loss: 0.11148139059838683, Train accuracy: 0.5182549504950495
# Validation loss: 0.14232503942080907, Validation accuracy: 0.38392857142857145
# Epoch: 7, LR: [2]
# Train loss: 0.10913276008450158, Train accuracy: 0.5399133663366337
# Validation loss: 0.13181932696274348, Validation accuracy: 0.41964285714285715
# Epoch: 8, LR: [2]
# Train loss: 0.10835540766763214, Train accuracy: 0.5570853960396039
# Validation loss: 0.1279588011758668, Validation accuracy: 0.3950892857142857
# Epoch: 9, LR: [2]
# Train loss: 0.10633403763617619, Train accuracy: 0.5716274752475248
# Validation loss: 0.14238823524543218, Validation accuracy: 0.3794642857142857
# Epoch: 10, LR: [2]
# Train loss: 0.10494154913000542, Train accuracy: 0.583384900990099
# Validation loss: 0.13792797923088074, Validation accuracy: 0.43526785714285715
# Epoch: 11, LR: [2]
# Train loss: 0.10411912601182957, Train accuracy: 0.5968440594059405
# Validation loss: 0.13681173643895558, Validation accuracy: 0.36830357142857145
# Epoch: 12, LR: [2]
# Train loss: 0.10256071978866464, Train accuracy: 0.6033415841584159
# Validation loss: 0.1336408012679645, Validation accuracy: 0.4419642857142857
# Epoch: 13, LR: [2]
# Train loss: 0.10149764321228065, Train accuracy: 0.6245358910891089
# Validation loss: 0.138571030327252, Validation accuracy: 0.43526785714285715
# Epoch: 14, LR: [2]
# Train loss: 0.10274234244433961, Train accuracy: 0.6209777227722773
# Validation loss: 0.12706062304122107, Validation accuracy: 0.44419642857142855
# Epoch: 15, LR: [2]
# Train loss: 0.10114931684024263, Train accuracy: 0.6333539603960396
# Validation loss: 0.13933176121541432, Validation accuracy: 0.37723214285714285
# Epoch: 16, LR: [2]
# Train loss: 0.10055603094325208, Train accuracy: 0.6376856435643564
# Validation loss: 0.13293725784335816, Validation accuracy: 0.48660714285714285
# Epoch: 17, LR: [2]
# Train loss: 0.09997138285105771, Train accuracy: 0.6451113861386139
# Validation loss: 0.12360169525657382, Validation accuracy: 0.46651785714285715
# Epoch: 18, LR: [2]
# Train loss: 0.09929966911821082, Train accuracy: 0.6574876237623762
# Validation loss: 0.14221911345209395, Validation accuracy: 0.46651785714285715
# Epoch: 19, LR: [2]
# Train loss: 0.0985817740311717, Train accuracy: 0.6610457920792079
# Validation loss: 0.1250376914228712, Validation accuracy: 0.48660714285714285
# Epoch: 20, LR: [2]
# Train loss: 0.09871554684520949, Train accuracy: 0.6748143564356436
# Validation loss: 0.13897077100617544, Validation accuracy: 0.43526785714285715
# Epoch: 21, LR: [2]
# Train loss: 0.09789898578483279, Train accuracy: 0.6711014851485149
# Validation loss: 0.1387935791696821, Validation accuracy: 0.39955357142857145
# Epoch: 22, LR: [2]
# Train loss: 0.09696229857088316, Train accuracy: 0.6711014851485149
# Validation loss: 0.11941408153091158, Validation accuracy: 0.5200892857142857
# Epoch: 23, LR: [2]
# Train loss: 0.09718030514103351, Train accuracy: 0.6827042079207921
# Validation loss: 0.12458187980311257, Validation accuracy: 0.5044642857142857
# Epoch: 24, LR: [2]
# Train loss: 0.09628607399097763, Train accuracy: 0.6837871287128713
# Validation loss: 0.1362959338085992, Validation accuracy: 0.5178571428571429
# Epoch: 25, LR: [2]
# Train loss: 0.09541030132239407, Train accuracy: 0.6935334158415841
# Validation loss: 0.12875914573669434, Validation accuracy: 0.49107142857142855
# Epoch: 26, LR: [2]
# Train loss: 0.09642607578546694, Train accuracy: 0.6972462871287128
# Validation loss: 0.1388865996684347, Validation accuracy: 0.49776785714285715
# Epoch: 27, LR: [2]
# Train loss: 0.09616093920304043, Train accuracy: 0.6918316831683168
# Validation loss: 0.13571787199803761, Validation accuracy: 0.46651785714285715
# Epoch: 28, LR: [2]
# Train loss: 0.09464678913354874, Train accuracy: 0.7004950495049505
# Validation loss: 0.12394600680896214, Validation accuracy: 0.5066964285714286
# Epoch: 29, LR: [2]
# Train loss: 0.09520602750011009, Train accuracy: 0.7025061881188119
# Validation loss: 0.11558484605380467, Validation accuracy: 0.5334821428571429
# Epoch: 30, LR: [2]
# Train loss: 0.09425440135568676, Train accuracy: 0.7103960396039604
# Validation loss: 0.11790800094604492, Validation accuracy: 0.5669642857142857
# Epoch: 31, LR: [2]
# Train loss: 0.09409924220330644, Train accuracy: 0.7178217821782178
# Validation loss: 0.12898238641875132, Validation accuracy: 0.5178571428571429
# Epoch: 32, LR: [2]
# Train loss: 0.09409253889381296, Train accuracy: 0.7162747524752475
# Validation loss: 0.1214799668107714, Validation accuracy: 0.5200892857142857
# Epoch: 33, LR: [2]
# Train loss: 0.09349086364307026, Train accuracy: 0.7224628712871287
# Validation loss: 0.1274274598274912, Validation accuracy: 0.5758928571428571
# Epoch: 34, LR: [2]
# Train loss: 0.09260704390483328, Train accuracy: 0.7241646039603961
# Validation loss: 0.1272602922150067, Validation accuracy: 0.5446428571428571
# Epoch: 35, LR: [2]
# Train loss: 0.09432998395497257, Train accuracy: 0.7218440594059405
# Validation loss: 0.1407131158879825, Validation accuracy: 0.5334821428571429
# Epoch: 36, LR: [2]
# Train loss: 0.09175478910455609, Train accuracy: 0.7322091584158416
# Validation loss: 0.12696303852966853, Validation accuracy: 0.5714285714285714
# Epoch: 37, LR: [2]
# Train loss: 0.09117934734809517, Train accuracy: 0.7345297029702971
# Validation loss: 0.12366298479693276, Validation accuracy: 0.5691964285714286
# Epoch: 38, LR: [2]
# Train loss: 0.08987988627488071, Train accuracy: 0.7430383663366337
# Validation loss: 0.14470505395105906, Validation accuracy: 0.5290178571428571
# Epoch: 39, LR: [2]
# Train loss: 0.08991066639376159, Train accuracy: 0.7405631188118812
# Validation loss: 0.13517042781625474, Validation accuracy: 0.5870535714285714
# Epoch: 40, LR: [2]
# Train loss: 0.09176762025840211, Train accuracy: 0.7484529702970297
# Validation loss: 0.12810789793729782, Validation accuracy: 0.5357142857142857
# Epoch: 41, LR: [2]
# Train loss: 0.09086813814569228, Train accuracy: 0.744894801980198
# Validation loss: 0.13940425430025374, Validation accuracy: 0.5446428571428571
# Epoch: 42, LR: [2]
# Train loss: 0.08959308753509333, Train accuracy: 0.7509282178217822
# Validation loss: 0.12958369510514395, Validation accuracy: 0.5267857142857143
# Epoch: 43, LR: [2]
# Train loss: 0.08948708945276714, Train accuracy: 0.7538675742574258
# Validation loss: 0.1484789592879159, Validation accuracy: 0.49330357142857145
# Epoch: 44, LR: [2]
# Train loss: 0.09140845919304555, Train accuracy: 0.7591274752475248
# Validation loss: 0.12936455330678395, Validation accuracy: 0.5803571428571429
# Epoch: 45, LR: [2]
# Train loss: 0.08971274046614619, Train accuracy: 0.7569616336633663
# Validation loss: 0.13281297896589553, Validation accuracy: 0.5401785714285714
# Epoch: 46, LR: [2]
# Train loss: 0.08894671389076969, Train accuracy: 0.7660891089108911
# Validation loss: 0.14934733510017395, Validation accuracy: 0.5245535714285714
# Epoch: 47, LR: [2]
# Train loss: 0.09041363318072687, Train accuracy: 0.7554146039603961
# Validation loss: 0.13120623358658381, Validation accuracy: 0.5334821428571429
# Epoch: 48, LR: [2]
# Train loss: 0.08897257256920975, Train accuracy: 0.7614480198019802
# Validation loss: 0.12678257269518717, Validation accuracy: 0.5535714285714286
# Epoch: 49, LR: [2]
# Train loss: 0.08872340604810432, Train accuracy: 0.7622215346534653
# Validation loss: 0.1575507926089423, Validation accuracy: 0.4732142857142857
# Epoch: 50, LR: [0.4]
# Train loss: 0.07801135149922701, Train accuracy: 0.8292079207920792
# Validation loss: 0.1166103162935802, Validation accuracy: 0.6339285714285714
# Epoch: 51, LR: [0.4]
# Train loss: 0.07367870333318663, Train accuracy: 0.8519492574257426
# Validation loss: 0.11563479368175779, Validation accuracy: 0.6205357142857143
# Epoch: 52, LR: [0.4]
# Train loss: 0.07181381544854382, Train accuracy: 0.8609220297029703
# Validation loss: 0.11777388836656298, Validation accuracy: 0.6517857142857143
# Epoch: 53, LR: [0.4]
# Train loss: 0.07137992148204605, Train accuracy: 0.8666460396039604
# Validation loss: 0.12487905046769551, Validation accuracy: 0.6026785714285714
# Epoch: 54, LR: [0.4]
# Train loss: 0.07091741381895424, Train accuracy: 0.8770111386138614
# Validation loss: 0.12381885732923235, Validation accuracy: 0.6339285714285714
# Epoch: 55, LR: [0.4]
# Train loss: 0.07003897325237199, Train accuracy: 0.8729888613861386
# Validation loss: 0.12149677106312343, Validation accuracy: 0.6383928571428571
# Epoch: 56, LR: [0.4]
# Train loss: 0.06927313961752571, Train accuracy: 0.885519801980198
# Validation loss: 0.12288164453847068, Validation accuracy: 0.6294642857142857
# Epoch: 57, LR: [0.4]
# Train loss: 0.06945015405221741, Train accuracy: 0.8841274752475248
# Validation loss: 0.12499424921614784, Validation accuracy: 0.6205357142857143
# Epoch: 58, LR: [0.4]
# Train loss: 0.06882336470160154, Train accuracy: 0.890315594059406
# Validation loss: 0.12047481962612697, Validation accuracy: 0.6339285714285714
# Epoch: 59, LR: [0.4]
# Train loss: 0.06838692868552586, Train accuracy: 0.8935643564356436
# Validation loss: 0.1214277840086392, Validation accuracy: 0.6227678571428571
# Epoch: 60, LR: [0.4]
# Train loss: 0.0682257001131478, Train accuracy: 0.8980507425742574
# Validation loss: 0.12928119514669692, Validation accuracy: 0.6227678571428571
# Epoch: 61, LR: [0.4]
# Train loss: 0.06782294090579052, Train accuracy: 0.895884900990099
# Validation loss: 0.1271471008658409, Validation accuracy: 0.6227678571428571
# Epoch: 62, LR: [0.4]
# Train loss: 0.06773616845654969, Train accuracy: 0.9030012376237624
# Validation loss: 0.13066659229142324, Validation accuracy: 0.6071428571428571
# Epoch: 63, LR: [0.4]
# Train loss: 0.06799726947994515, Train accuracy: 0.8975866336633663
# Validation loss: 0.13024837310825074, Validation accuracy: 0.6116071428571429
# Epoch: 64, LR: [0.08000000000000002]
# Train loss: 0.0667876442617709, Train accuracy: 0.9056311881188119
# Validation loss: 0.12297853933913368, Validation accuracy: 0.6584821428571429
# Epoch: 65, LR: [0.08000000000000002]
# Train loss: 0.06628425430395815, Train accuracy: 0.9107363861386139
# Validation loss: 0.12827724431242263, Validation accuracy: 0.6272321428571429
# Epoch: 66, LR: [0.08000000000000002]
# Train loss: 0.0666933449556922, Train accuracy: 0.9067141089108911
# Validation loss: 0.1263483464717865, Validation accuracy: 0.6205357142857143
# Epoch: 67, LR: [0.08000000000000002]
# Train loss: 0.06607141423195896, Train accuracy: 0.9146039603960396
# Validation loss: 0.12162885282720838, Validation accuracy: 0.6294642857142857
# Epoch: 68, LR: [0.08000000000000002]
# Train loss: 0.06600929615963803, Train accuracy: 0.9146039603960396
# Validation loss: 0.12660407274961472, Validation accuracy: 0.6294642857142857
# Epoch: 69, LR: [0.08000000000000002]
# Train loss: 0.06579021932465015, Train accuracy: 0.9152227722772277
# Validation loss: 0.1221575800861631, Validation accuracy: 0.6473214285714286
# Epoch: 70, LR: [0.08000000000000002]
# Train loss: 0.06619343014046697, Train accuracy: 0.9110457920792079
# Validation loss: 0.12260500873838152, Validation accuracy: 0.6160714285714286
# Target number of exemplars per class: 66
# Target total number of exemplars: 1980
# Randomly extracting exemplars from class 0 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 66 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 66 exemplars.
# Computing mean of exemplars... done
# Test accuracy (iCaRL): 0.703 (exemplars and training data)
# gridsearch rfc . . .
# gridsearch knn . . .
# gridsearch svc . . .
# gridsearch done.
# Test accuracy (iCaRL with RFC): 0.5313333333333333
# Test accuracy (iCaRL with KNN): 0.6803333333333333
# Test accuracy (iCaRL with SVC): 0.695
# ## Split 3 of run 0 ##
# Length of exemplars set: 1980
# Epoch: 1, LR: [2]
# Train loss: 0.11944199287065185, Train accuracy: 0.3225556930693069
# Validation loss: 0.11366188951901027, Validation accuracy: 0.20535714285714285
# Epoch: 2, LR: [2]
# Train loss: 0.10189513618698215, Train accuracy: 0.42048267326732675
# Validation loss: 0.11643236662660326, Validation accuracy: 0.2857142857142857
# Epoch: 3, LR: [2]
# Train loss: 0.09879273604048361, Train accuracy: 0.46395420792079206
# Validation loss: 0.12262301572731563, Validation accuracy: 0.3080357142857143
# Epoch: 4, LR: [2]
# Train loss: 0.09647301031221257, Train accuracy: 0.49257425742574257
# Validation loss: 0.10797713696956635, Validation accuracy: 0.39955357142857145
# Epoch: 5, LR: [2]
# Train loss: 0.09564038336572081, Train accuracy: 0.5171720297029703
# Validation loss: 0.117440222629479, Validation accuracy: 0.35714285714285715
# Epoch: 6, LR: [2]
# Train loss: 0.09455685944545388, Train accuracy: 0.5400680693069307
# Validation loss: 0.11618668160268239, Validation accuracy: 0.40401785714285715
# Epoch: 7, LR: [2]
# Train loss: 0.09291840883174746, Train accuracy: 0.5697710396039604
# Validation loss: 0.11560813656875066, Validation accuracy: 0.42410714285714285
# Epoch: 8, LR: [2]
# Train loss: 0.09277162199268246, Train accuracy: 0.5682240099009901
# Validation loss: 0.10631137767008372, Validation accuracy: 0.45089285714285715
# Epoch: 9, LR: [2]
# Train loss: 0.09181062250149132, Train accuracy: 0.594059405940594
# Validation loss: 0.11442664691380092, Validation accuracy: 0.3705357142857143
# Epoch: 10, LR: [2]
# Train loss: 0.092081583888814, Train accuracy: 0.6104579207920792
# Validation loss: 0.10873844793864659, Validation accuracy: 0.4330357142857143
# Epoch: 11, LR: [2]
# Train loss: 0.09175371688486327, Train accuracy: 0.6161819306930693
# Validation loss: 0.11240204423666, Validation accuracy: 0.43080357142857145
# Epoch: 12, LR: [2]
# Train loss: 0.09109327654437263, Train accuracy: 0.6373762376237624
# Validation loss: 0.10198811335223061, Validation accuracy: 0.5044642857142857
# Epoch: 13, LR: [2]
# Train loss: 0.08987319078480843, Train accuracy: 0.6434096534653465
# Validation loss: 0.10526940545865468, Validation accuracy: 0.48660714285714285
# Epoch: 14, LR: [2]
# Train loss: 0.09048530680708367, Train accuracy: 0.6523824257425742
# Validation loss: 0.1105920108301299, Validation accuracy: 0.44419642857142855
# Epoch: 15, LR: [2]
# Train loss: 0.08936536289972834, Train accuracy: 0.6550123762376238
# Validation loss: 0.10505461054188865, Validation accuracy: 0.45535714285714285
# Epoch: 16, LR: [2]
# Train loss: 0.08990466439782983, Train accuracy: 0.6593440594059405
# Validation loss: 0.1061643117240497, Validation accuracy: 0.5223214285714286
# Epoch: 17, LR: [2]
# Train loss: 0.08974118523373462, Train accuracy: 0.6641398514851485
# Validation loss: 0.10916904998677117, Validation accuracy: 0.4263392857142857
# Epoch: 18, LR: [2]
# Train loss: 0.08868772979124938, Train accuracy: 0.6789913366336634
# Validation loss: 0.11293683626822063, Validation accuracy: 0.4486607142857143
# Epoch: 19, LR: [2]
# Train loss: 0.08961470875114498, Train accuracy: 0.677444306930693
# Validation loss: 0.104060312466962, Validation accuracy: 0.5044642857142857
# Epoch: 20, LR: [2]
# Train loss: 0.08922797397221668, Train accuracy: 0.6870358910891089
# Validation loss: 0.10791826461042676, Validation accuracy: 0.5089285714285714
# Epoch: 21, LR: [2]
# Train loss: 0.08835488683221364, Train accuracy: 0.6887376237623762
# Validation loss: 0.10953801338161741, Validation accuracy: 0.5491071428571429
# Epoch: 22, LR: [2]
# Train loss: 0.0887889960909834, Train accuracy: 0.6895111386138614
# Validation loss: 0.1111060476728848, Validation accuracy: 0.5580357142857143
# Epoch: 23, LR: [2]
# Train loss: 0.08819152791016173, Train accuracy: 0.7074566831683168
# Validation loss: 0.11469897734267372, Validation accuracy: 0.53125
# Epoch: 24, LR: [2]
# Train loss: 0.08819469602981417, Train accuracy: 0.7014232673267327
# Validation loss: 0.12243664477552686, Validation accuracy: 0.47544642857142855
# Epoch: 25, LR: [2]
# Train loss: 0.08794024918634112, Train accuracy: 0.7068378712871287
# Validation loss: 0.11601474774735314, Validation accuracy: 0.48214285714285715
# Epoch: 26, LR: [2]
# Train loss: 0.08811595401551464, Train accuracy: 0.7054455445544554
# Validation loss: 0.11692282876798085, Validation accuracy: 0.5513392857142857
# Epoch: 27, LR: [2]
# Train loss: 0.08798129908224143, Train accuracy: 0.7090037128712872
# Validation loss: 0.10818467076335635, Validation accuracy: 0.5357142857142857
# Epoch: 28, LR: [2]
# Train loss: 0.08700190521407836, Train accuracy: 0.7202970297029703
# Validation loss: 0.10652215140206474, Validation accuracy: 0.5379464285714286
# Epoch: 29, LR: [2]
# Train loss: 0.08797893437123534, Train accuracy: 0.7117883663366337
# Validation loss: 0.10227563338620323, Validation accuracy: 0.53125
# Epoch: 30, LR: [2]
# Train loss: 0.08650187262804201, Train accuracy: 0.7300433168316832
# Validation loss: 0.11042173206806183, Validation accuracy: 0.53125
# Epoch: 31, LR: [2]
# Train loss: 0.08663600838125342, Train accuracy: 0.7280321782178217
# Validation loss: 0.10269988115344729, Validation accuracy: 0.5580357142857143
# Epoch: 32, LR: [2]
# Train loss: 0.08581088763652461, Train accuracy: 0.7390160891089109
# Validation loss: 0.10266435252768653, Validation accuracy: 0.6049107142857143
# Epoch: 33, LR: [2]
# Train loss: 0.08647437570708813, Train accuracy: 0.7349938118811881
# Validation loss: 0.10496110788413457, Validation accuracy: 0.5892857142857143
# Epoch: 34, LR: [2]
# Train loss: 0.08649114526734494, Train accuracy: 0.7353032178217822
# Validation loss: 0.11402585889611926, Validation accuracy: 0.5022321428571429
# Epoch: 35, LR: [2]
# Train loss: 0.08646305539820454, Train accuracy: 0.7379331683168316
# Validation loss: 0.11722927221230098, Validation accuracy: 0.5647321428571429
# Epoch: 36, LR: [2]
# Train loss: 0.08660963111289657, Train accuracy: 0.7527846534653465
# Validation loss: 0.1162924702678408, Validation accuracy: 0.4732142857142857
# Epoch: 37, LR: [2]
# Train loss: 0.08691613744981218, Train accuracy: 0.7379331683168316
# Validation loss: 0.10182152369192668, Validation accuracy: 0.59375
# Epoch: 38, LR: [2]
# Train loss: 0.08661262359064405, Train accuracy: 0.7421101485148515
# Validation loss: 0.11634329812867301, Validation accuracy: 0.5669642857142857
# Epoch: 39, LR: [2]
# Train loss: 0.08733733227052311, Train accuracy: 0.7462871287128713
# Validation loss: 0.11473272847277778, Validation accuracy: 0.53125
# Epoch: 40, LR: [2]
# Train loss: 0.08494162662784652, Train accuracy: 0.7546410891089109
# Validation loss: 0.1109718871968133, Validation accuracy: 0.5625
# Epoch: 41, LR: [2]
# Train loss: 0.08598647738742356, Train accuracy: 0.7462871287128713
# Validation loss: 0.11460144179207939, Validation accuracy: 0.48660714285714285
# Epoch: 42, LR: [2]
# Train loss: 0.08614899822981051, Train accuracy: 0.7543316831683168
# Validation loss: 0.10999942358051028, Validation accuracy: 0.5401785714285714
# Epoch: 43, LR: [2]
# Train loss: 0.08439133080220458, Train accuracy: 0.765315594059406
# Validation loss: 0.10268958977290563, Validation accuracy: 0.6049107142857143
# Epoch: 44, LR: [2]
# Train loss: 0.08608876264626437, Train accuracy: 0.7622215346534653
# Validation loss: 0.12279285596949714, Validation accuracy: 0.5133928571428571
# Epoch: 45, LR: [2]
# Train loss: 0.08561758239670555, Train accuracy: 0.7612933168316832
# Validation loss: 0.11972337003265109, Validation accuracy: 0.5111607142857143
# Epoch: 46, LR: [2]
# Train loss: 0.08440112920090703, Train accuracy: 0.7674814356435643
# Validation loss: 0.10202722677162715, Validation accuracy: 0.59375
# Epoch: 47, LR: [2]
# Train loss: 0.08425349513492962, Train accuracy: 0.7747524752475248
# Validation loss: 0.10489873162337712, Validation accuracy: 0.5848214285714286
# Epoch: 48, LR: [2]
# Train loss: 0.08483419168998699, Train accuracy: 0.7716584158415841
# Validation loss: 0.1145621846829142, Validation accuracy: 0.5178571428571429
# Epoch: 49, LR: [2]
# Train loss: 0.08527946767240467, Train accuracy: 0.7736695544554455
# Validation loss: 0.1232222393155098, Validation accuracy: 0.49330357142857145
# Epoch: 50, LR: [0.4]
# Train loss: 0.07791299026201268, Train accuracy: 0.812809405940594
# Validation loss: 0.10225431408200945, Validation accuracy: 0.6004464285714286
# Epoch: 51, LR: [0.4]
# Train loss: 0.07426671337078114, Train accuracy: 0.8398824257425742
# Validation loss: 0.10307095838444573, Validation accuracy: 0.6138392857142857
# Epoch: 52, LR: [0.4]
# Train loss: 0.07341199803470384, Train accuracy: 0.8457611386138614
# Validation loss: 0.10523896664381027, Validation accuracy: 0.6361607142857143
# Epoch: 53, LR: [0.4]
# Train loss: 0.07293510802163936, Train accuracy: 0.8567450495049505
# Validation loss: 0.10712795065982002, Validation accuracy: 0.6227678571428571
# Epoch: 54, LR: [0.4]
# Train loss: 0.07241769046476572, Train accuracy: 0.8666460396039604
# Validation loss: 0.1048493395958628, Validation accuracy: 0.59375
# Epoch: 55, LR: [0.4]
# Train loss: 0.07233142546645485, Train accuracy: 0.864944306930693
# Validation loss: 0.10728733880179268, Validation accuracy: 0.6361607142857143
# Epoch: 56, LR: [0.4]
# Train loss: 0.07158592472424602, Train accuracy: 0.8674195544554455
# Validation loss: 0.1041210943034717, Validation accuracy: 0.6116071428571429
# Epoch: 57, LR: [0.4]
# Train loss: 0.07129415537756269, Train accuracy: 0.8722153465346535
# ...
# gridsearch rfc . . .
# gridsearch knn . . .
# gridsearch svc . . .
# gridsearch done.
# Test accuracy (iCaRL with RFC): 0.258
# Test accuracy (iCaRL with KNN): 0.5296
# Test accuracy (iCaRL with SVC): 0.553
# ## Split 5 of run 0 ##
# Length of exemplars set: 2000
# Epoch: 1, LR: [2]
# Train loss: 0.11860872052683688, Train accuracy: 0.2755259900990099
# Validation loss: 0.09574538043567113, Validation accuracy: 0.14955357142857142
# Epoch: 2, LR: [2]
# Train loss: 0.10954767664765368, Train accuracy: 0.35844678217821785
# Validation loss: 0.09109532833099365, Validation accuracy: 0.24776785714285715
# Epoch: 3, LR: [2]
# Train loss: 0.10745438653053624, Train accuracy: 0.42620668316831684
# Validation loss: 0.08804231137037277, Validation accuracy: 0.3169642857142857
# Epoch: 4, LR: [2]
# Train loss: 0.1058772401791988, Train accuracy: 0.46642945544554454
# Validation loss: 0.0898768710238593, Validation accuracy: 0.37723214285714285
# Epoch: 5, LR: [2]
# Train loss: 0.10463188839430856, Train accuracy: 0.5083539603960396
# Validation loss: 0.07862684982163566, Validation accuracy: 0.4575892857142857
# Epoch: 6, LR: [2]
# Train loss: 0.10388192032823468, Train accuracy: 0.5307858910891089
# Validation loss: 0.08127546949045998, Validation accuracy: 0.4419642857142857
# Epoch: 7, LR: [2]
# Train loss: 0.10338348378934482, Train accuracy: 0.5618811881188119
# Validation loss: 0.08268361432211739, Validation accuracy: 0.4642857142857143
# Epoch: 8, LR: [2]
# Train loss: 0.1027186720235513, Train accuracy: 0.5751856435643564
# Validation loss: 0.08301362821034022, Validation accuracy: 0.4642857142857143
# Epoch: 9, LR: [2]
# Train loss: 0.10216223699326563, Train accuracy: 0.6027227722772277
# Validation loss: 0.08693840673991612, Validation accuracy: 0.4330357142857143
# Epoch: 10, LR: [2]
# Train loss: 0.10215559409986628, Train accuracy: 0.5991646039603961
# Validation loss: 0.08445025661161967, Validation accuracy: 0.5223214285714286
# Epoch: 11, LR: [2]
# Train loss: 0.10188550258627033, Train accuracy: 0.6166460396039604
# Validation loss: 0.09056815079280309, Validation accuracy: 0.4107142857142857
# Epoch: 12, LR: [2]
# Train loss: 0.10135637474532175, Train accuracy: 0.6274752475247525
# Validation loss: 0.08956009468861989, Validation accuracy: 0.44419642857142855
# Epoch: 13, LR: [2]
# Train loss: 0.10103653931971823, Train accuracy: 0.6341274752475248
# Validation loss: 0.08381567788975579, Validation accuracy: 0.5044642857142857
# Epoch: 14, LR: [2]
# Train loss: 0.09984906386620927, Train accuracy: 0.6543935643564357
# Validation loss: 0.0848563898886953, Validation accuracy: 0.484375
# Epoch: 15, LR: [2]
# Train loss: 0.10069263851878667, Train accuracy: 0.6551670792079208
# Validation loss: 0.0788798885686057, Validation accuracy: 0.5491071428571429
# Epoch: 16, LR: [2]
# Train loss: 0.10013626493734888, Train accuracy: 0.6503712871287128
# Validation loss: 0.08046210663659233, Validation accuracy: 0.5267857142857143
# Epoch: 17, LR: [2]
# Train loss: 0.09981743836461908, Train accuracy: 0.6743502475247525
# Validation loss: 0.08438582186188016, Validation accuracy: 0.5424107142857143
# Epoch: 18, LR: [2]
# Train loss: 0.09981606679387611, Train accuracy: 0.6653774752475248
# Validation loss: 0.08395288033144814, Validation accuracy: 0.5379464285714286
# Epoch: 19, LR: [2]
# Train loss: 0.09952553073958595, Train accuracy: 0.671875
# Validation loss: 0.08681580530745643, Validation accuracy: 0.48660714285714285
# Epoch: 20, LR: [2]
# Train loss: 0.09938321697829973, Train accuracy: 0.6839418316831684
# Validation loss: 0.08368498193366188, Validation accuracy: 0.5290178571428571
# Epoch: 21, LR: [2]
# Train loss: 0.09918802364332842, Train accuracy: 0.6896658415841584
# Validation loss: 0.08007576635905675, Validation accuracy: 0.5558035714285714
# Epoch: 22, LR: [2]
# Train loss: 0.09879126126813416, Train accuracy: 0.6964727722772277
# Validation loss: 0.0875672772526741, Validation accuracy: 0.5022321428571429
# Epoch: 23, LR: [2]
# Train loss: 0.09893527029469462, Train accuracy: 0.6905940594059405
# Validation loss: 0.07882330673081535, Validation accuracy: 0.49776785714285715
# Epoch: 24, LR: [2]
# Train loss: 0.09903150959180133, Train accuracy: 0.6987933168316832
# Validation loss: 0.0872312496815409, Validation accuracy: 0.5200892857142857
# Epoch: 25, LR: [2]
# Train loss: 0.09782843564701553, Train accuracy: 0.708230198019802
# Validation loss: 0.08240411430597305, Validation accuracy: 0.5424107142857143
# Epoch: 26, LR: [2]
# Train loss: 0.09811043363101411, Train accuracy: 0.7056002475247525
# Validation loss: 0.10114295674221856, Validation accuracy: 0.4419642857142857
# Epoch: 27, LR: [2]
# Train loss: 0.09827990734046048, Train accuracy: 0.7107054455445545
# Validation loss: 0.07667954159634453, Validation accuracy: 0.5580357142857143
# Epoch: 28, LR: [2]
# Train loss: 0.0981276074405944, Train accuracy: 0.7054455445544554
# Validation loss: 0.08483761868306569, Validation accuracy: 0.5535714285714286
# Epoch: 29, LR: [2]
# Train loss: 0.09829457613206145, Train accuracy: 0.7085396039603961
# Validation loss: 0.08271997741290502, Validation accuracy: 0.5558035714285714
# Epoch: 30, LR: [2]
# Train loss: 0.09772232691250225, Train accuracy: 0.7202970297029703
# Validation loss: 0.07956100361687797, Validation accuracy: 0.5892857142857143
# Epoch: 31, LR: [2]
# Train loss: 0.09769821616977749, Train accuracy: 0.7218440594059405
# Validation loss: 0.08388465642929077, Validation accuracy: 0.5401785714285714
# Epoch: 32, LR: [2]
# Train loss: 0.09731849482153902, Train accuracy: 0.7258663366336634
# Validation loss: 0.08232709446123668, Validation accuracy: 0.6049107142857143
# Epoch: 33, LR: [2]
# Train loss: 0.0967242657990739, Train accuracy: 0.7360767326732673
# Validation loss: 0.07787803347621645, Validation accuracy: 0.5736607142857143
# Epoch: 34, LR: [2]
# Train loss: 0.09697821352741506, Train accuracy: 0.7283415841584159
# Validation loss: 0.07746558423553195, Validation accuracy: 0.5535714285714286
# Epoch: 35, LR: [2]
# Train loss: 0.09685702444893299, Train accuracy: 0.729424504950495
# Validation loss: 0.08633287463869367, Validation accuracy: 0.5245535714285714
# Epoch: 36, LR: [2]
# Train loss: 0.0973713364046399, Train accuracy: 0.7325185643564357
# Validation loss: 0.08471345475741796, Validation accuracy: 0.5580357142857143
# Epoch: 37, LR: [2]
# Train loss: 0.09658858755437455, Train accuracy: 0.7349938118811881
# Validation loss: 0.08888408648116249, Validation accuracy: 0.5825892857142857
# Epoch: 38, LR: [2]
# Train loss: 0.097163424559749, Train accuracy: 0.7314356435643564
# Validation loss: 0.07800800459725517, Validation accuracy: 0.5758928571428571
# Epoch: 39, LR: [2]
# Train loss: 0.09700321479894147, Train accuracy: 0.7397896039603961
# Validation loss: 0.09383254923990794, Validation accuracy: 0.5535714285714286
# Epoch: 40, LR: [2]
# Train loss: 0.0962449315160808, Train accuracy: 0.7363861386138614
# Validation loss: 0.08787235617637634, Validation accuracy: 0.5580357142857143
# Epoch: 41, LR: [2]
# Train loss: 0.09629926476443168, Train accuracy: 0.749690594059406
# Validation loss: 0.0916680885212762, Validation accuracy: 0.5602678571428571
# Epoch: 42, LR: [2]
# Train loss: 0.09643326950545358, Train accuracy: 0.7414913366336634
# Validation loss: 0.07576770228999001, Validation accuracy: 0.5959821428571429
# Epoch: 43, LR: [2]
# Train loss: 0.09685003550926058, Train accuracy: 0.739480198019802
# Validation loss: 0.08176708966493607, Validation accuracy: 0.5848214285714286
# Epoch: 44, LR: [2]
# Train loss: 0.09631558677347579, Train accuracy: 0.7461324257425742
# Validation loss: 0.08049722760915756, Validation accuracy: 0.5535714285714286
# Epoch: 45, LR: [2]
# Train loss: 0.09600667943163674, Train accuracy: 0.7462871287128713
# Validation loss: 0.08433632233313151, Validation accuracy: 0.5714285714285714
# Epoch: 46, LR: [2]
# Train loss: 0.09614264677361686, Train accuracy: 0.7479888613861386
# Validation loss: 0.0858728928225381, Validation accuracy: 0.5066964285714286
# Epoch: 47, LR: [2]
# Train loss: 0.09582762678365896, Train accuracy: 0.7544863861386139
# Validation loss: 0.08568771396364484, Validation accuracy: 0.5647321428571429
# Epoch: 48, LR: [2]
# Train loss: 0.09531538800732924, Train accuracy: 0.7636138613861386
# Validation loss: 0.07617252107177462, Validation accuracy: 0.5848214285714286
# Epoch: 49, LR: [2]
# Train loss: 0.09687248499381661, Train accuracy: 0.7452042079207921
# Validation loss: 0.09089108875819615, Validation accuracy: 0.546875
# Epoch: 50, LR: [0.4]
# Train loss: 0.09077708415760852, Train accuracy: 0.8197710396039604
# Validation loss: 0.0779155290552548, Validation accuracy: 0.6071428571428571
# Epoch: 51, LR: [0.4]
# Train loss: 0.08828867426013003, Train accuracy: 0.838799504950495
# Validation loss: 0.07727737511907305, Validation accuracy: 0.609375
# Epoch: 52, LR: [0.4]
# Train loss: 0.0874000491187124, Train accuracy: 0.8391089108910891
# Validation loss: 0.0809686609676906, Validation accuracy: 0.6026785714285714
# Epoch: 53, LR: [0.4]
# Train loss: 0.08693578610620877, Train accuracy: 0.8539603960396039
# Validation loss: 0.0795037831578936, Validation accuracy: 0.625
# Epoch: 54, LR: [0.4]
# Train loss: 0.08661277481529972, Train accuracy: 0.8551980198019802
# Validation loss: 0.07890700016702924, Validation accuracy: 0.59375
# Epoch: 55, LR: [0.4]
# Train loss: 0.08636703401213826, Train accuracy: 0.8627784653465347
# Validation loss: 0.07757110893726349, Validation accuracy: 0.5959821428571429
# Epoch: 56, LR: [0.4]
# Train loss: 0.08641265959727883, Train accuracy: 0.8570544554455446
# Validation loss: 0.07977279062782015, Validation accuracy: 0.6183035714285714
# Epoch: 57, LR: [0.4]
# Train loss: 0.08591144111486945, Train accuracy: 0.8621596534653465
# Validation loss: 0.07931234794003623, Validation accuracy: 0.6026785714285714
# Epoch: 58, LR: [0.4]
# Train loss: 0.08575813516531841, Train accuracy: 0.8621596534653465
# Validation loss: 0.08200149876730782, Validation accuracy: 0.5915178571428571
# Epoch: 59, LR: [0.4]
# Train loss: 0.08544837676062442, Train accuracy: 0.8671101485148515
# Validation loss: 0.08339478501251765, Validation accuracy: 0.59375
# Epoch: 60, LR: [0.4]
# Train loss: 0.08554281508273417, Train accuracy: 0.8674195544554455
# Validation loss: 0.08074407918112618, Validation accuracy: 0.6183035714285714
# Epoch: 61, LR: [0.4]
# Train loss: 0.08539005376324796, Train accuracy: 0.8678836633663366
# Validation loss: 0.08050724544695445, Validation accuracy: 0.625
# Epoch: 62, LR: [0.4]
# Train loss: 0.0852917190825585, Train accuracy: 0.8702042079207921
# Validation loss: 0.07912251033953258, Validation accuracy: 0.6205357142857143
# Epoch: 63, LR: [0.4]
# Train loss: 0.08506922084506195, Train accuracy: 0.8768564356435643
# Validation loss: 0.08258918885673795, Validation accuracy: 0.6004464285714286
# Epoch: 64, LR: [0.08000000000000002]
# Train loss: 0.08513378860926864, Train accuracy: 0.8780940594059405
# Validation loss: 0.081951519208295, Validation accuracy: 0.6004464285714286
# Epoch: 65, LR: [0.08000000000000002]
# Train loss: 0.08471896558409871, Train accuracy: 0.880105198019802
# Validation loss: 0.08113703770296914, Validation accuracy: 0.6049107142857143
# Epoch: 66, LR: [0.08000000000000002]
# Train loss: 0.0844678259131932, Train accuracy: 0.8791769801980198
# Validation loss: 0.08182503815208163, Validation accuracy: 0.5982142857142857
# Epoch: 67, LR: [0.08000000000000002]
# Train loss: 0.08447286907103982, Train accuracy: 0.885365099009901
# Validation loss: 0.08025023234742028, Validation accuracy: 0.6071428571428571
# Epoch: 68, LR: [0.08000000000000002]
# Train loss: 0.08456902840349934, Train accuracy: 0.8822710396039604
# Validation loss: 0.08183898563895907, Validation accuracy: 0.6138392857142857
# Epoch: 69, LR: [0.08000000000000002]
# Train loss: 0.0843936821611801, Train accuracy: 0.8819616336633663
# Validation loss: 0.08255995277847562, Validation accuracy: 0.609375
# Epoch: 70, LR: [0.08000000000000002]
# Train loss: 0.08448144114843689, Train accuracy: 0.8821163366336634
# Validation loss: 0.08289233701569694, Validation accuracy: 0.5803571428571429
# Target number of exemplars per class: 33
# Target total number of exemplars: 1980
# Randomly extracting exemplars from class 0 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 1 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 2 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 3 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 4 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 5 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 6 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 7 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 8 of current split... Extracted 33 exemplars.
# Randomly extracting exemplars from class 9 of current split... Extracted 33 exemplars.
# Computing mean of exemplars... done
# Test accuracy (iCaRL): 0.5628333333333333 (exemplars and training data)
# gridsearch rfc . . .
# gridsearch knn . . .
# gridsearch svc . . .
# gridsearch done.
# Test accuracy (iCaRL with RFC): 0.20216666666666666
# Test accuracy (iCaRL with KNN): 0.4846666666666667
# Test accuracy (iCaRL with SVC): 0.5145
# ## Split 6 of run 0 ##
# Length of exemplars set: 1980
# Epoch: 1, LR: [2]
# Train loss: 0.10491203465084038, Train accuracy: 0.35426980198019803
# Validation loss: 0.07800623455217906, Validation accuracy: 0.3236607142857143
# Epoch: 2, LR: [2]
# Train loss: 0.09620110247984971, Train accuracy: 0.49489480198019803
# Validation loss: 0.07509304476635796, Validation accuracy: 0.46205357142857145
# Epoch: 3, LR: [2]
# Train loss: 0.0949295064305315, Train accuracy: 0.5323329207920792
# Validation loss: 0.07427343406847545, Validation accuracy: 0.5245535714285714
# Epoch: 4, LR: [2]
# Train loss: 0.09384598162504706, Train accuracy: 0.567605198019802
# Validation loss: 0.06902670115232468, Validation accuracy: 0.5290178571428571
# Epoch: 5, LR: [2]
# Train loss: 0.0931523858320595, Train accuracy: 0.5935952970297029
# Validation loss: 0.0709015993135316, Validation accuracy: 0.6116071428571429
# Epoch: 6, LR: [2]
# Train loss: 0.09281045663179738, Train accuracy: 0.6166460396039604
# Validation loss: 0.0714569091796875, Validation accuracy: 0.6049107142857143
# Epoch: 7, LR: [2]
# Train loss: 0.09311983977804089, Train accuracy: 0.6288675742574258
# Validation loss: 0.07174643980605262, Validation accuracy: 0.609375
# Epoch: 8, LR: [2]
# Train loss: 0.09166394786374403, Train accuracy: 0.6489789603960396
# Validation loss: 0.06817705929279327, Validation accuracy: 0.6495535714285714
# Epoch: 9, LR: [2]
# Train loss: 0.09127906879576125, Train accuracy: 0.655940594059406
# Validation loss: 0.06415389052459172, Validation accuracy: 0.6584821428571429
# Epoch: 10, LR: [2]
# Train loss: 0.09101235645242256, Train accuracy: 0.6728032178217822
# Validation loss: 0.07073939272335597, Validation accuracy: 0.6450892857142857
# Epoch: 11, LR: [2]
# Train loss: 0.09125755188783796, Train accuracy: 0.6655321782178217
# Validation loss: 0.07335857514824186, Validation accuracy: 0.6361607142857143
# Epoch: 12, LR: [2]
# Train loss: 0.09105772480811222, Train accuracy: 0.6864170792079208
# Validation loss: 0.06985773571899959, Validation accuracy: 0.6339285714285714
# Epoch: 13, LR: [2]
# Train loss: 0.09047115203177575, Train accuracy: 0.6953898514851485
# Validation loss: 0.07241023864064898, Validation accuracy: 0.6607142857142857
# Epoch: 14, LR: [2]
# Train loss: 0.09027545449167194, Train accuracy: 0.698174504950495
# Validation loss: 0.06502881326845714, Validation accuracy: 0.6852678571428571
# Epoch: 15, LR: [2]
# Train loss: 0.09042428522416861, Train accuracy: 0.7113242574257426
# Validation loss: 0.0619074675653662, Validation accuracy: 0.6741071428571429
# Epoch: 16, LR: [2]
# Train loss: 0.0899299797740313, Train accuracy: 0.7158106435643564
# Validation loss: 0.07505344599485397, Validation accuracy: 0.6763392857142857
# Epoch: 17, LR: [2]
# Train loss: 0.09053021890692192, Train accuracy: 0.7167388613861386
# Validation loss: 0.07016812264919281, Validation accuracy: 0.6741071428571429
# Epoch: 18, LR: [2]
